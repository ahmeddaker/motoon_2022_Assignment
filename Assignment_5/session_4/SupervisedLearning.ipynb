# %% [markdown]
# # How Supervised Learning Problem Formalized Mathematically
# - Generally there are two approaches to formalize the supervised problem (regression or classification) which are
#     - <b>Discriminative methods:</b> where the algorithm tries to find a boundary between different classes. This boundary discriminate classes
#     - <b>Generative methods:</b> where the algorithm tries to find a probability distribution for every class in terms of feature values. This probability distribution calculates the probability of the class given the feature vector
#
# <img src="images/GenerativeVsDiscrimenative.png" width=420 align="middle">

# %% [markdown]
# ## Discriminative Models
# 1- <b>In regression</b> we assumes there is function (for example n-d curve) that represents the relation between the feature vector and the target value<br/>
#
# <b>For Example:</b> we may need to estimate the salary of an employee based on her/his caracteristics. Here the function parameters (variables) are the employee's caracteristics. And the target is the value of the employee salary
#
# 2- <b>In classificationd</b> we assumes there is a function that represents a separator between two classes (in the binary classification problem).

# %% [markdown]
# ## Linear Regression
# An algorithm used to estimate a continues value from observations. For example detect the price of the house from its features.<br/>
#
# ### How Linear Regression works
# 1- Assume an intial function for the target value (for example the house price)<br/>
# y = W * X + b<br/>
# X: the feature vectore<br/>
# W: the weight of the feature vector<br/>
# b: the bias vectore<br/>
# Note: that this is the general equation of the hyper plan
#
# 2- The target is  to minimize the error between the actual y (actual houses prices) and the calculated y from the assumed function
#
# 3- So, the target value is minimize (y - y`). Instead of dealing with the actual difference between the calculated y and the the actual y, we use the square value of the difference
#
# 4- Then the problem will be formalized as minimizing the square difference between the actual y and the calculated y (this is called optimization problem)
#
# <img src="images/LinearRegressionAnim.gif" width=500></img>

# %%
import numpy as np

# Load data from CSV file
# - column 1: population (x)
# - column 2: profit (y)
data = np.loadtxt('data/lr/ex1data1.txt', delimiter=',')
# Separate features (x) from target (y)
X, y = np.hsplit(data, 2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt


plt.plot(X, y, 'bx', label='Data')
plt.plot(X, model.predict(X), 'r-', label='Regression')
plt.xlabel('Population')
plt.ylabel('Profit')
plt.legend()

print(model.score(X, y))
# Out:
# 0.7020315537841397

# %% [markdown]
# ## Gradient Decent
# <img src="images/GradientDescentGIF.gif" width=500></img>
# 1- Gradient descent is a mathematical algorithm that targets to get function's minimum value

# %% [markdown]
# ## Assignment
#  1- load california housing data-set from kit-learn using the following function:
#  sklearn.datasets.fetch_california_housing </br>
#  2- Perform feature scaling
#  3- train regressor with each feature and the target housing price</br>
#  4- draw a plot between each regressor and the housing price</br>
#  5- get the score of each regressor</br>
#  6- train a regressor with all the features and the target housing price</br>
#  7- get the score with each regressor</br>

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# Import dataset
from sklearn.datasets import fetch_california_housing
X, y = fetch_california_housing(return_X_y=True, as_frame=True)
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: MedHouseVal, dtype: float64

# %%
# data types
X.dtypes
# Out:
# MedInc        float64
# HouseAge      float64
# AveRooms      float64
# AveBedrms     float64
# Population    float64
# AveOccup      float64
# Latitude      float64
# Longitude     float64
# dtype: object

# %%
# scaling data 
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X_scaled.shape
# Out:
# (20640, 8)

# %%
# split data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Show the results of the split
print("Training set has {} samples.".format(X_train.shape[0]))
print("Testing set has {} samples.".format(X_test.shape[0]))
# Out:
# Training set has 16512 samples.
# Testing set has 4128 samples.

# %%
# importing regression models
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import HuberRegressor
from sklearn.linear_model import Lars
from sklearn.linear_model import LassoLars
from sklearn.linear_model import OrthogonalMatchingPursuit
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression

# Import evaluation metrics
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Create a list of regression models
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), 
        KNeighborsRegressor(), SVR(), Ridge(), Lasso(), ElasticNet(), SGDRegressor(), 
        PassiveAggressiveRegressor(), RANSACRegressor(), HuberRegressor(), Lars(), LassoLars(), 
        OrthogonalMatchingPursuit(), BayesianRidge(), ARDRegression()]

results = []
# Train each model on the training set
for model in models:
    model.fit(X_train, y_train)
    print("{} : score {}".format(model.__class__.__name__, model.score(X_test, y_test)))
    results.append(model.score(X_test, y_test))
    # Make predictions on the test set
    y_pred = model.predict(X_test)
    # Print the evaluation of each model on the test set
    print("{} : R2 {}".format(model.__class__.__name__, r2_score(y_test, y_pred)))
    print("{} : mean_squared_error {}".format(model.__class__.__name__, mean_squared_error(y_test, y_pred)))
    print("{} : mean_absolute_error {}".format(model.__class__.__name__, mean_absolute_error(y_test, y_pred)))
    # Plot the results
    plt.plot(y_test, y_pred, 'bx', label='Predictions')
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.legend()
    plt.show()
# Out:
# LinearRegression : score 0.5757877060324512
# LinearRegression : R2 0.5757877060324512
# LinearRegression : mean_squared_error 0.5558915986952437
# LinearRegression : mean_absolute_error 0.5332001304956557
# DecisionTreeRegressor : score 0.6273821543395575
# DecisionTreeRegressor : R2 0.6273821543395575
# DecisionTreeRegressor : mean_squared_error 0.4882817704062258
# DecisionTreeRegressor : mean_absolute_error 0.4550626671511629
# RandomForestRegressor : score 0.806963239623331
# RandomForestRegressor : R2 0.806963239623331
# RandomForestRegressor : mean_squared_error 0.2529571039281242
# RandomForestRegressor : mean_absolute_error 0.3271362855862404
# KNeighborsRegressor : score 0.6892455644426327
# KNeighborsRegressor : R2 0.6892455644426327
# KNeighborsRegressor : mean_squared_error 0.40721540238255716
# KNeighborsRegressor : mean_absolute_error 0.4266654375
# SVR : score 0.63826754538279
# SVR : R2 0.63826754538279
# SVR : mean_squared_error 0.47401745625151087
# SVR : mean_absolute_error 0.4583604832870259
# Ridge : score 0.5841235955401214
# Ridge : R2 0.5841235955401214
# Ridge : mean_squared_error 0.5449681742427686
# Ridge : mean_absolute_error 0.5392147056503739
# Lasso : score -0.00021908714592466794
# Lasso : R2 -0.00021908714592466794
# Lasso : mean_squared_error 1.3106960720039365
# Lasso : mean_absolute_error 0.9060685490007149
# ElasticNet : score -0.00021908714592466794
# ElasticNet : R2 -0.00021908714592466794
# ElasticNet : mean_squared_error 1.3106960720039365
# ElasticNet : mean_absolute_error 0.9060685490007149
# SGDRegressor : score 0.551121205188855
# SGDRegressor : R2 0.551121205188855
# SGDRegressor : mean_squared_error 0.5882148028624791
# SGDRegressor : mean_absolute_error 0.5615666334508751
# PassiveAggressiveRegressor : score -0.6194960175372508
# PassiveAggressiveRegressor : R2 -0.6194960175372508
# PassiveAggressiveRegressor : mean_squared_error 2.1222021216061946
# PassiveAggressiveRegressor : mean_absolute_error 1.2469227589595966
# RANSACRegressor : score 0.3644974428106823
# RANSACRegressor : R2 0.3644974428106823
# RANSACRegressor : mean_squared_error 0.8327682566359327
# RANSACRegressor : mean_absolute_error 0.5462471343234534
# HuberRegressor : score 0.5561065957706516
# HuberRegressor : R2 0.5561065957706516
# HuberRegressor : mean_squared_error 0.581681902284055
# HuberRegressor : mean_absolute_error 0.5188647898358006
# c:\Users\CompuMisr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_huber.py:332: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\CompuMisr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py:133: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# Lars : score 0.575787706032451
# Lars : R2 0.575787706032451
# Lars : mean_squared_error 0.5558915986952442
# Lars : mean_absolute_error 0.5332001304956564
# c:\Users\CompuMisr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py:133: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LassoLars())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# LassoLars : score -0.00021908714592466794
# LassoLars : R2 -0.00021908714592466794
# LassoLars : mean_squared_error 1.3106960720039365
# LassoLars : mean_absolute_error 0.9060685490007149
# OrthogonalMatchingPursuit : score 0.45885918903846656
# OrthogonalMatchingPursuit : R2 0.45885918903846656
# OrthogonalMatchingPursuit : mean_squared_error 0.7091157771765548
# OrthogonalMatchingPursuit : mean_absolute_error 0.6299086530093763
# c:\Users\CompuMisr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py:133: FutureWarning: The default of 'normalize' will be set to False in version 1.2 and deprecated in version 1.4.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), OrthogonalMatchingPursuit())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# BayesianRidge : score 0.5761494344572915
# BayesianRidge : R2 0.5761494344572915
# BayesianRidge : mean_squared_error 0.5554175865196481
# BayesianRidge : mean_absolute_error 0.5332367683226702
# ARDRegression : score 0.5758344360200489
# ARDRegression : R2 0.5758344360200489
# ARDRegression : mean_squared_error 0.5558303632999426
# ARDRegression : mean_absolute_error 0.5332160562725871

# %%
# print best model
print(models[results.index(max(results))].__class__.__name__)
# Out:
# RandomForestRegressor
